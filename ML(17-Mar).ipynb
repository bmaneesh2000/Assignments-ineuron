# %%
#1

""" 
Q1: What are missing values in a dataset? Why is it essential to handle missing values? Name some
algorithms that are not affected by missing values.
"""

#Answers

""" 
Missing Values :-

Missing Values occur when some of the information is not stored for a variable dur to various reasons

All the machine learning algorithms don't support missing values but some ML algorithms are robust to missing values in the dataset. 
The k-NN algorithm can ignore a column from a distance measure when a value is missing. Naive Bayes can also support missing values when making a prediction.

"""

# %%
#2

""" 
Q2: List down techniques used to handle missing data. Give an example of each with python code.
"""

#Answers

""" 
-Mean Value Imputation     
-Mean Value Imputation    
-Mode Imputation          
-Random Sample Imputation
"""
""" 

df["col"].fillna(df['col'].mean)

df["col"].fillna(df['col'].median)

mode=df[df["col"].notna()]["col"].mode()[0]
df["col"].fillna(mode-value)

"""

# %%
#3

""" 
Q3: Explain the imbalanced data. What will happen if imbalanced data is not handled?
"""

#Answers

""" 
Imbalanced Dataset :-

A classification data set with skewed class proportions is called imbalanced. 
Classes that make up a large proportion of the data set are called majority classes. 
Those that make up a smaller proportion are minority classes

If imbalanced dataset is not handled the model can become biased towards the majority class.
"""

# %%
#4

""" 
Q4: What are Up-sampling and Down-sampling? Explain with an example when up-sampling and down-
sampling are required.
"""

#Answers

""" 
Upsampling- The minority data class is interpolated and increaed to an more proportional number

DownSampling-Take the minority sample and reduce it to size comparable to the minority sample

example:-

dataset - 1: 900, 0: 100
upsampling: 1:900, 0:900
downsampling : 1:100 , 0:100
"""

# %%
#5

""" 
Q5: What is data Augmentation? Explain SMOTE.
"""

#Answers

#Data Augmentation

""" 
Data augmentation is a technique of artificially increasing the training set by creating modified copies of a dataset using existing data.

SMOTE :- SMOTE (synthetic minority oversampling technique) is one of the most commonly used oversampling methods to solve the imbalance problem.
It aims to balance class distribution by randomly increasing minority class examples by replicating them.
SMOTE synthesises new minority instances between existing minority instances. It generates the virtual training records by linear interpolation for the minority class. 
These synthetic training records are generated by randomly selecting one or more of the k-nearest neighbors for each example in the minority class. 
After the oversampling process, the data is reconstructed and several classification models can be applied for the processed data.
"""

# %%
#6

""" 
Q6: What are outliers in a dataset? Why is it essential to handle outliers?
"""

#Answers

""" 
Outiers :- Outliers are those data points that are significantly different from the rest of the dataset. 
They are often abnormal observations that skew the data distribution, and arise due to inconsistent data entry, or erroneous observations.

It is essential to handle the outliers as they can negatively affect the statistical analysis and the training process of a machine learning algorithm resulting in lower accuracy
"""

# %%
#7

""" 
Q7: You are working on a project that requires analyzing customer data. However, you notice that some of
the data is missing. What are some techniques you can use to handle the missing data in your analysis?
"""

#Answer

""" 
We will use imputation to fill up the missing values
Mean Value Imputation
Median Value Imputaution
Random value imputation
"""

# %%
#8

"""
Q8: You are working with a large dataset and find that a small percentage of the data is missing. What are
some strategies you can use to determine if the missing data is missing at random or if there is a pattern
to the missing data?
"""

#Answers

""" 
We will use imputation to fill up the missing values
Mean Value Imputation
"""

# %%
#9

""" 
Q9: Suppose you are working on a medical diagnosis project and find that the majority of patients in the
dataset do not have the condition of interest, while a small percentage do. What are some strategies you
can use to evaluate the performance of your machine learning model on this imbalanced dataset?
"""

#Answer

""" 
Use SMOTE technique to artificially increasing the training set by creating modified copies of a dataset using existing data.
"""

# %%
#10

"""
Q10: When attempting to estimate customer satisfaction for a project, you discover that the dataset is
unbalanced, with the bulk of customers reporting being satisfied. What methods can you employ to
balance the dataset and down-sample the majority class?
"""

#Answers

""" 
We can downsample the majority class to create an more equitable dataset, but will have loss of data
"""

# %%
#11

""" 
Q11: You discover that the dataset is unbalanced with a low percentage of occurrences while working on a
project that requires you to estimate the occurrence of a rare event. What methods can you employ to
balance the dataset and up-sample the minority class?
"""

#Answers

""" 
Use SMOTE technique
"""
